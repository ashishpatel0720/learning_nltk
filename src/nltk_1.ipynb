# %%
import nltk
import matplotlib.pyplot as pp
import numpy as np
print("importing modules")
# Out:
# importing modules

# %%
arr=np.arange(0,10,.1)

pp.plot(arr,np.sin(arr))
pp.plot(arr,np.cos(arr))
pp.grid
